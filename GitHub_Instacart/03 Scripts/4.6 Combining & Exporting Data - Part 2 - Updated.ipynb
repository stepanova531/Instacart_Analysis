# %% [markdown]
# # 01 Importing libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing data

# %%
# Create strings for path
path=r'C:\Users\Oksana Stepanova\OneDrive\Документи\Instacart Basket Analysis'

# %%
# Import Orders-Products combined dataframe
df_ords=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_product_combined.pkl'))

# %%
df_ords.shape
# Out:
# (32434489, 11)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243449e+07  3.243449e+07  3.243449e+07        3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01        2.738818e+00
# std    9.873007e+05  5.946648e+04  1.753504e+01        2.090049e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00        1.000000e+00
# 50%    1.711048e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243449e+07            3.035642e+07  3.243449e+07
# mean        1.342498e+01            1.110407e+01  2.557634e+04
# std         4.246365e+00            8.778914e+00  1.409669e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
# Import Products dataframe 
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_prods.shape
# Out:
# (49670, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49670.000000  49670.000000  49670.000000   49670.000000  49670.000000
# mean   24851.894000  24850.238716     67.761305      11.728770      7.680437
# std    14342.492172  14340.931850     38.316060       5.850834      4.199381
# min        0.000000      1.000000      1.000000       1.000000      1.000000
# 25%    12432.250000  12432.250000     35.000000       7.000000      4.100000
# 50%    24851.500000  24850.500000     69.000000      13.000000      7.100000
# 75%    37272.750000  37268.750000    100.000000      17.000000     11.100000
# max    49692.000000  49688.000000    134.000000      21.000000     25.000000

# %%
# Drop '_merge' column on Orders
df_ords=df_ords.drop(columns=['_merge'])

# %%
df_ords.shape
# Out:
# (32434489, 10)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243449e+07  3.243449e+07  3.243449e+07        3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01        2.738818e+00
# std    9.873007e+05  5.946648e+04  1.753504e+01        2.090049e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00        1.000000e+00
# 50%    1.711048e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243449e+07            3.035642e+07  3.243449e+07
# mean        1.342498e+01            1.110407e+01  2.557634e+04
# std         4.246365e+00            8.778914e+00  1.409669e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
df_ords.dtypes
# Out:
# order_id                    int32
# user_id                     int32
# order_number                int16
# orders_day_of_week           int8
# order_hour_of_day            int8
# days_since_prior_order    float64
# first_order                  bool
# product_id                  int32
# add_to_cart_order           int16
# reordered                    int8
# dtype: object

# %%
# Check for data type on Products 
df_prods.dtypes
# Out:
# Unnamed: 0         int64
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %%
# Drop Unnamed column on Products 
df_prods=df_prods.drop(columns=['Unnamed: 0'])

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Optimize data type on Products
df_prods_optim3=df_prods.astype({'product_id':'int32', 'aisle_id':'int16', 'department_id':'int8'})

# %%
df_prods_optim3.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49670.000000  49670.000000   49670.000000  49670.000000
# mean   24850.238716     67.761305      11.728770      7.680437
# std    14340.931850     38.316060       5.850834      4.199381
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.250000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.750000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000     25.000000

# %%
df_prods_optim3.dtypes
# Out:
# product_id         int32
# product_name      object
# aisle_id           int16
# department_id       int8
# prices           float64
# dtype: object

# %% [markdown]
# # 03 Merging Products and Orders dataframes

# %%
# Merge Orders and Products using inner join by default
df_merge1=df_ords.merge(df_prods_optim3, on='product_id', indicator=True)

# %%
# Check for the data on df_merge1
df_merge1.shape
# Out:
# (32399732, 15)

# %%
df_merge1.dtypes
# Out:
# order_id                     int32
# user_id                      int32
# order_number                 int16
# orders_day_of_week            int8
# order_hour_of_day             int8
# days_since_prior_order     float64
# first_order                   bool
# product_id                   int32
# add_to_cart_order            int16
# reordered                     int8
# product_name                object
# aisle_id                     int16
# department_id                 int8
# prices                     float64
# _merge                    category
# dtype: object

# %%
df_merge1.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.239973e+07  3.239973e+07  3.239973e+07        3.239973e+07
# mean   1.710746e+06  1.029367e+05  1.714260e+01        2.738865e+00
# std    9.872994e+05  5.946623e+04  1.753544e+01        2.090089e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559450e+05  5.142000e+04  5.000000e+00        1.000000e+00
# 50%    1.711052e+06  1.026140e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543880e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.239973e+07            3.032399e+07  3.239973e+07
# mean        1.342514e+01            1.110395e+01  2.559904e+04
# std         4.246397e+00            8.779012e+00  1.408498e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# # 04 Exporting data

# %%
# Export Orders-Product-Merged dataframe
df_merge1.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
